# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import eda_helpers as helper

# %%
file_path = '../../data/processed/departures.csv'

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#                                          id  \
# 0      0004f240-509d-44f9-b11b-d8073c27afda
# 1      00056fc0-99e2-45e6-90a7-4ce6246a6eb6
# 2      000c7ae0-9477-45d8-837b-cb5fde089f08
# 3      001243e9-05c9-4253-a216-970efb5af371
# 4      0016b268-72a9-4157-9c8f-55a989e8464c
# ...                                     ...
# 15883  ffe55e72-66cc-4467-94c4-a4e1ed296705
# 15884  ffe58ae1-40ba-40c3-a364-d12a84eb72e3
# 15885  ffe8fd9c-4b87-4c52-b75e-078e8041adc5
# 15886  fff2a284-b366-40d2-b37a-1cdd0cde704c
# 15887  fffaa6a2-1841-4025-8503-85d0b2363913
#
#                                  fkSeasonId  \
# 0      f154feeb-a55e-4506-8028-ca98aaac4824
# 1      612219fb-e6ad-4917-bbe7-ae9c910cc005
# 2      136c7b8f-35e8-4d39-98b4-6e94a688364f
# 3      42f89d56-7d21-4ef9-af90-30f756ce6d14
# 4      b656e118-82a1-4826-a571-7f06c92576d7
# ...                                     ...
# 15883  4d2520ac-5a8d-4a27-a379-a0dfabfa3aa8
# 15884  aa2beaf2-604d-4e85-8262-0b5551fa29cc
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15888 entries, 0 to 15887
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              15888 non-null  object
#  1   fkSeasonId      15888 non-null  object
#  2   fkTourOptionId  15888 non-null  object
#  3   startDate       15888 non-null  object
#  4   endDate         15888 non-null  object
#  5   availability    15888 non-null  object
#  6   created_at      15888 non-null  object
#  7   updated_at      15888 non-null  object
# dtypes: object(8)
# memory usage: 993.1+ KB

# %%
data['availability'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Decisions:**
# - Remove: 'id', 'fkSeasonId', 'fkTourOptionId', 'created_at', 'updated_at'
# - Use: 'startDate', 'endDate',
#        'availability'

# %%
data.columns
# Out:
# Index(['id', 'fkSeasonId', 'fkTourOptionId', 'startDate', 'endDate',
#        'availability', 'created_at', 'updated_at'],
#       dtype='object')

# %%
print("Start Date Range: ", data['startDate'].min(), "to", data['startDate'].max())
print("End Date Range: ", data['endDate'].min(), "to", data['endDate'].max())
# Out:
# Start Date Range:  2023-01-10 to 2026-04-07
# End Date Range:  2023-01-21 to 2026-04-16

# %%
plt.figure(figsize=(12, 6))

plt.hist(data['startDate'], bins=30, alpha=0.5, label='Start Date')
plt.hist(data['endDate'], bins=30, alpha=0.5, label='End Date')

plt.title('Distribution of Start and End Dates')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.show()

# %%
data['startDate'] = pd.to_datetime(data['startDate'])
data['endDate'] = pd.to_datetime(data['endDate'])

# %%
plt.figure(figsize=(12, 6))

data.set_index('startDate').resample('M').size().plot(label='Start Date', linewidth=2)
data.set_index('endDate').resample('M').size().plot(label='End Date', linewidth=2)

plt.title('Number of departures over time')
plt.ylabel('Number of departures')
plt.xlabel('Time')
plt.legend()
plt.show()
